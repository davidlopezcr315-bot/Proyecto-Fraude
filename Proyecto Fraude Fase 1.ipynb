# %% [markdown]
# # 🎓 Proyecto Fin de Máster: Detección de Fraude
# #    Importar librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from datetime import datetime
from IPython.display import display

print("✅ All necessary libraries have been imported successfully.")
# Out:
# ✅ All necessary libraries have been imported successfully.

# %% [markdown]
# ### Fase 1: Exploración y Diagnóstico
# - [ ] Cargar todos los datasets
# - [ ] Analizar estructura y tipos de datos
# - [ ] Identificar todos los problemas de calidad
# - [ ] Documentar hallazgos

# %%
# Cargar todos los datasets

transactions = pd.read_csv('transactions.csv', sep=';')
countries = pd.read_csv('countries.csv')
devices = pd.read_csv('devices.csv', sep=';')
merchants = pd.read_csv('merchants.csv')
users = pd.read_csv('users.csv')


print("✅ Datasets cargados exitosamente.")
# Out:
# ✅ Datasets cargados exitosamente.

# %%
# Analizar las primeras filas de cada dataset

print("Transactions Dataset:")
display(transactions.head())

print("Countries Dataset:")
display(countries.head())

print("Devices Dataset:")
display(devices.head())

print("Merchants Dataset:")
display(merchants.head())

print("Users Dataset:")
display(users.head())

print("=" * 120)  

#Analizar estructura de los datos y estadísticas descriptivas
print("\nTransactions Dataset Info:")
display(transactions.info())
print("\nTransactions Dataset Description:")
display(transactions.describe(include='all'))

print("\nCountries Dataset Info:")
display(countries.info())
print("\nCountries Dataset Description:")
display(countries.describe(include='all'))

print("\nDevices Dataset Info:")
display(devices.info())
print("\nDevices Dataset Description:")
display(devices.describe(include='all'))

print("\nMerchants Dataset Info:")
display(merchants.info())
print("\nMerchants Dataset Description:")
display(merchants.describe(include='all'))

print("\nUsers Dataset Info:")
display(users.info())
print("\nUsers Dataset Description:")
display(users.describe(include='all'))
# Out:
# Transactions Dataset:
#    transaction_id  user_id  account_age_days  total_transactions_user  \
# 0               1        1               141                       47
# 1               2        1               141                       47
# 2               3        1               141                       47
# 3               4        1               141                       47
# 4               5        1               141                       47
#
#    avg_amount_user  amount country bin_country channel merchant_category  \
# 0           147.93   84.75      FR          FR     web            travel
# 1           147.93   107.9      FR          FR     web            travel
# 2           147.93   92.36      FR          FR     app            travel
# 3           147.93  112.47      FR          FR     web           fashion
# 4           147.93  132.91      FR          US     web       electronics
#
#    promo_used  avs_match  cvv_result  three_ds_flag      transaction_time  \
# ...

# %%
# Identificar problemas de calidad de datos

def identify_data_issues(df, df_name):
    print(f"\nData Quality Issues in {df_name} Dataset:")
    
    # Valores nulos
    null_counts = df.isnull().sum()
    print("\nNull Values:")
    display(null_counts[null_counts > 0])
    
    # Duplicados
    duplicate_count = df.duplicated().sum()
    print(f"\nDuplicate Rows: {duplicate_count}")
    
    # Tipos de datos inconsistentes
    print("\nData Types:")
    display(df.dtypes)
    
    # Valores atípicos (usando IQR para variables numéricas)
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    for col in numeric_cols:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        outliers = df[(df[col] < (Q1 - 1.5 * IQR)) | (df[col] > (Q3 + 1.5 * IQR))]
        print(f"\nOutliers in {col}: {len(outliers)}")
        display(outliers)
